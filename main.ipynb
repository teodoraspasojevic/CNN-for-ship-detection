# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, cv2, pickle, json, itertools
import imgaug.augmenters as iaa
import imgaug.imgaug

from IPython.display import SVG
from keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.utils import class_weight
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer

from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import (Add, Input, Conv2D, Dropout, Activation, BatchNormalization, MaxPooling2D, ZeroPadding2D, AveragePooling2D, Flatten, Dense)
from keras.optimizers import Adam, SGD
from keras.callbacks import TensorBoard, ModelCheckpoint, Callback
from keras.preprocessing.image import ImageDataGenerator
from keras.initializers import *

# %%
def show_final_history(history):
    
    plt.style.use("ggplot")
    fig, ax = plt.subplots(1,2,figsize=(15,5))
    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')
    ax[0].plot(history.history['loss'],label='Train Loss')
    ax[0].plot(history.history['val_loss'],label='Validation Loss')
    ax[1].plot(history.history['accuracy'],label='Train Accuracy')
    ax[1].plot(history.history['val_accuracy'],label='Validation Accuracy')
    
    ax[0].legend(loc='upper right')
    ax[1].legend(loc='lower right')
    plt.show();

# %%
def plot_confusion_matrix(cm,classes,title='Confusion Matrix',cmap=plt.cm.Blues):

    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes,rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f'
    thresh = cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                horizontalalignment="center",
                color="white" if cm[i,j] > thresh else "black")
        pass
    
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    pass

# %%
datasets = ['input']

class_names = ["no-ship","ship"]

class_name_labels = {class_name:i for i,class_name in enumerate(class_names)}

num_classes = len(class_names)
class_name_labels
# Out:
# {'no-ship': 0, 'ship': 1}

# %%
def load_data():
    images, labels = [], []
    
    for dataset in datasets:
        
        for folder in os.listdir(dataset):
            label = class_name_labels[folder]
            
            for file in tqdm(os.listdir(os.path.join(dataset,folder))):
                
                img_path = os.path.join(dataset,folder,file)
                
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (48,48))
                
                images.append(img)
                labels.append(label)
                pass
            pass
        
        images = np.array(images,dtype=np.float32)/255.0
        labels = np.array(labels,dtype=np.float32)
        pass
    
    return (images, labels)
    pass

# %%
(images, labels) = load_data()
images.shape, labels.shape
# Out:
# 100%|██████████| 3000/3000 [00:01<00:00, 2429.73it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2476.42it/s]
# ((4000, 48, 48, 3), (4000,))

# %%
n_labels = labels.shape[0]

_, count = np.unique(labels, return_counts=True)

df = pd.DataFrame(data = count)
df['Class Label'] = class_names
df.columns = ['Count','Class-Label']
df.set_index('Class-Label',inplace=True)
df
# Out:
#              Count
# Class-Label
# no-ship       3000
# ship          1000

# %%
df.plot.bar(rot=0)
plt.title("distribution of images per class");

# %%
plt.pie(count,
       explode=(0,0),
       labels=class_names,
       autopct="%1.2f%%")
plt.axis('equal');

# %%
AUGMENTATION = True

# %%
def augment_add(images, seq, labels):
    
    augmented_images, augmented_labels = [],[]
    for idx,img in tqdm(enumerate(images)):
        
        if labels[idx] == 1:
            image_aug_1 = seq.augment_image(image=img)
            image_aug_2 = seq.augment_image(image=img)
            augmented_images.append(image_aug_1)
            augmented_images.append(image_aug_2)
            augmented_labels.append(labels[idx])
            augmented_labels.append(labels[idx])
        pass
    
    augmented_images = np.array(augmented_images, dtype=np.float32)
    augmented_labels = np.array(augmented_labels, dtype=np.float32)
    
    return (augmented_images, augmented_labels)
    pass

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0,0.1)),
    iaa.LinearContrast((0.75,1.5)),
    iaa.Multiply((0.8,1.2), per_channel=0.2),
    iaa.Affine(
        scale={'x':(0.8,1.2), "y":(0.8,1.2)},
        translate_percent={"x":(-0.2,0.2),"y":(-0.2,0.2)},
        rotate=(-25,25),
        shear=(-8,8)
    )
], random_order=True) #filteri se random primenjuju

# %%
if AUGMENTATION:
    (aug_images, aug_labels) = augment_add(images, seq, labels)
    images = np.concatenate([images, aug_images])
    labels = np.concatenate([labels, aug_labels])
# Out:
# 4000it [00:03, 1311.63it/s]

# %%
images.shape, labels.shape
# Out:
# ((6000, 48, 48, 3), (6000,))

# %%
if AUGMENTATION:
    _, count = np.unique(labels, return_counts=True)

    plt.pie(count,
           explode=(0,0),
           labels=class_names,
           autopct="%1.2f%%")
    plt.axis('equal');

# %%
labels = to_categorical(labels)

# %%
np.random.seed(42)
np.random.shuffle(images)

np.random.seed(42)
np.random.shuffle(labels)

# %%
total_count = len(images)

train = int(0.7*total_count)
val = int(0.2*total_count)
test = int(0.1*total_count)

train_images, train_labels = images[:train], labels[:train]
val_images, val_labels = images[train:(val+train)], labels[train:(val+train)]
test_images, test_labels = images[-test:], labels[-test:]

train_images.shape, val_images.shape, test_images.shape
# Out:
# ((4200, 48, 48, 3), (1200, 48, 48, 3), (600, 48, 48, 3))

# %%
if not AUGMENTATION:
    count_labels = train_labels.sum(axis=0) #sabira sve keceve

    classTotals = train_labels.sum(axis=0)
    classWeight = {}

    for i in range(0,len(classTotals)):
        classWeight[i] = classTotals.max()/classTotals[i]
        pass
    print(classWeight)

# %%
def conv_block(X,k,filters,stage,block,s=2):
    
    conv_base_name = 'conv_' + str(stage)+block+'_branch'
    bn_base_name = 'bn_'+str(stage)+block+"_branch"
    
    F1 = filters
    
    X = Conv2D(filters=F1, kernel_size=(k,k), strides=(s,s),
              padding='same',name=conv_base_name+'2a')(X)
    X = BatchNormalization(name=bn_base_name+'2a')(X)
    X = Activation('relu')(X)
    
    return X
    pass

# %%
def basic_model(input_shape,classes):
    
    X_input = Input(input_shape)
    
    X = ZeroPadding2D((5,5))(X_input)
    
    X = Conv2D(16,(3,3),strides=(2,2),name='conv1',padding="same")(X)
    X = BatchNormalization(name='bn_conv1')(X)
    
    # stage 2
    X = conv_block(X,3,32,2,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)

#     Stage 3
    X = conv_block(X,5,32,3,block='A',s=2)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#     Stage 4
    X = conv_block(X,3,64,4,block='A',s=1)
    X = MaxPooling2D((2,2))(X)
    X = Dropout(0.25)(X)
    
#   Output Layer
    X = Flatten()(X)
    X = Dense(64)(X)
    X = Dropout(0.5)(X)
    
    X = Dense(128)(X)
    X = Activation("relu")(X)
    
    X = Dense(classes,activation="softmax",name="fc"+str(classes))(X)
    
    model = Model(inputs=X_input,outputs=X,name='Feature_Extraction_and_FC')
    
    return model
    pass

# %%
model = basic_model(input_shape=(48,48,3),classes=2)

# %%
#plot_model(model,to_file='basic_model.png')

model.summary()
# Out:
# Model: "Feature_Extraction_and_FC"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  zero_padding2d (ZeroPadding  (None, 58, 58, 3)        0
#  2D)
#
#  conv1 (Conv2D)              (None, 29, 29, 16)        448
#
#  bn_conv1 (BatchNormalizatio  (None, 29, 29, 16)       64
#  n)
#
#  conv_2A_branch2a (Conv2D)   (None, 29, 29, 32)        4640
#
#  bn_2A_branch2a (BatchNormal  (None, 29, 29, 32)       128
#  ization)
#
#  activation (Activation)     (None, 29, 29, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv_3A_branch2a (Conv2D)   (None, 7, 7, 32)          25632
#
#  bn_3A_branch2a (BatchNormal  (None, 7, 7, 32)         128
#  ization)
#
#  activation_1 (Activation)   (None, 7, 7, 32)          0
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 32)          0
#
#  conv_4A_branch2a (Conv2D)   (None, 3, 3, 64)          18496
#
#  bn_4A_branch2a (BatchNormal  (None, 3, 3, 64)         256
#  ization)
#
#  activation_2 (Activation)   (None, 3, 3, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  activation_3 (Activation)   (None, 128)               0
#
#  fc2 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 62,530
# Trainable params: 62,242
# Non-trainable params: 288
# _________________________________________________________________

# %%
opt = Adam(learning_rate=1e-3)
model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("model_weights.h5",monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
logs = TensorBoard("logs")  # ispisivanje metrike po eposi

# %%
epochs = 50
batch_size = 16

history = model.fit(train_images,train_labels,
                   steps_per_epoch=len(train_images)//batch_size,
                   epochs=epochs,
                   verbose=1, 
                   validation_data=(val_images,val_labels),
                   validation_steps=len(val_images)//batch_size,
                   callbacks=[checkpoint, logs]
#                    class_weight=classWeight # odkomentarisati ako je AUGMENTATION = FALSE
                   )
# Out:
# Epoch 1/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.3982 - accuracy: 0.8154
# Epoch 1: val_accuracy improved from -inf to 0.69333, saving model to model_weights.h5
# 262/262 [==============================] - 9s 32ms/step - loss: 0.3975 - accuracy: 0.8155 - val_loss: 0.5261 - val_accuracy: 0.6933
# Epoch 2/50
# 262/262 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9144
# Epoch 2: val_accuracy improved from 0.69333 to 0.95667, saving model to model_weights.h5
# 262/262 [==============================] - 9s 34ms/step - loss: 0.1986 - accuracy: 0.9144 - val_loss: 0.1201 - val_accuracy: 0.9567
# Epoch 3/50
# 262/262 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9432
# Epoch 3: val_accuracy did not improve from 0.95667
# 262/262 [==============================] - 9s 33ms/step - loss: 0.1593 - accuracy: 0.9432 - val_loss: 0.0962 - val_accuracy: 0.9567
# Epoch 4/50
# 262/262 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9581
# Epoch 4: val_accuracy improved from 0.95667 to 0.97833, saving model to model_weights.h5
# 262/262 [==============================] - 9s 33ms/step - loss: 0.1110 - accuracy: 0.9581 - val_loss: 0.0628 - val_accuracy: 0.9783
# Epoch 5/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.1043 - accuracy: 0.9606
# Epoch 5: val_accuracy did not improve from 0.97833
# 262/262 [==============================] - 10s 38ms/step - loss: 0.1040 - accuracy: 0.9608 - val_loss: 0.0602 - val_accuracy: 0.9775
# Epoch 6/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9681
# Epoch 6: val_accuracy did not improve from 0.97833
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0838 - accuracy: 0.9682 - val_loss: 0.0987 - val_accuracy: 0.9583
# Epoch 7/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9743
# Epoch 7: val_accuracy did not improve from 0.97833
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0663 - accuracy: 0.9743 - val_loss: 0.4896 - val_accuracy: 0.8408
# Epoch 8/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9752
# Epoch 8: val_accuracy improved from 0.97833 to 0.98333, saving model to model_weights.h5
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0678 - accuracy: 0.9752 - val_loss: 0.0434 - val_accuracy: 0.9833
# Epoch 9/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9799
# Epoch 9: val_accuracy improved from 0.98333 to 0.99167, saving model to model_weights.h5
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0601 - accuracy: 0.9799 - val_loss: 0.0318 - val_accuracy: 0.9917
# Epoch 10/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9819
# Epoch 10: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 10s 38ms/step - loss: 0.0533 - accuracy: 0.9820 - val_loss: 0.0463 - val_accuracy: 0.9842
# Epoch 11/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9767
# Epoch 11: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0601 - accuracy: 0.9768 - val_loss: 0.0789 - val_accuracy: 0.9708
# Epoch 12/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9838
# Epoch 12: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0460 - accuracy: 0.9838 - val_loss: 0.0720 - val_accuracy: 0.9750
# Epoch 13/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9820
# Epoch 13: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0551 - accuracy: 0.9820 - val_loss: 0.0357 - val_accuracy: 0.9892
# Epoch 14/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9860
# Epoch 14: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0421 - accuracy: 0.9860 - val_loss: 0.0342 - val_accuracy: 0.9892
# Epoch 15/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9790
# Epoch 15: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0631 - accuracy: 0.9790 - val_loss: 0.0468 - val_accuracy: 0.9833
# Epoch 16/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0447 - accuracy: 0.9851
# Epoch 16: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 31ms/step - loss: 0.0446 - accuracy: 0.9851 - val_loss: 0.0778 - val_accuracy: 0.9708
# Epoch 17/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9871
# Epoch 17: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.0533 - val_accuracy: 0.9825
# Epoch 18/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9903
# Epoch 18: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 8s 32ms/step - loss: 0.0316 - accuracy: 0.9903 - val_loss: 0.2307 - val_accuracy: 0.9358
# Epoch 19/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9847
# Epoch 19: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0449 - accuracy: 0.9847 - val_loss: 0.0324 - val_accuracy: 0.9867
# Epoch 20/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9892
# Epoch 20: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 0.0339 - val_accuracy: 0.9883
# Epoch 21/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9896
# Epoch 21: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0277 - accuracy: 0.9896 - val_loss: 0.0493 - val_accuracy: 0.9825
# Epoch 22/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9878
# Epoch 22: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 10s 40ms/step - loss: 0.0362 - accuracy: 0.9878 - val_loss: 0.0227 - val_accuracy: 0.9917
# Epoch 23/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9914
# Epoch 23: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 11s 42ms/step - loss: 0.0250 - accuracy: 0.9914 - val_loss: 0.0310 - val_accuracy: 0.9900
# Epoch 24/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9908
# Epoch 24: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 12s 47ms/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 0.0284 - val_accuracy: 0.9908
# Epoch 25/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9950
# Epoch 25: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 10s 38ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0537 - val_accuracy: 0.9850
# Epoch 26/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9899
# Epoch 26: val_accuracy did not improve from 0.99167
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0303 - accuracy: 0.9899 - val_loss: 0.0535 - val_accuracy: 0.9867
# Epoch 27/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9919
# Epoch 27: val_accuracy improved from 0.99167 to 0.99333, saving model to model_weights.h5
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.0252 - val_accuracy: 0.9933
# Epoch 28/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9887
# Epoch 28: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 10s 36ms/step - loss: 0.0272 - accuracy: 0.9887 - val_loss: 0.0331 - val_accuracy: 0.9933
# Epoch 29/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9928
# Epoch 29: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.0805 - val_accuracy: 0.9758
# Epoch 30/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9930
# Epoch 30: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0206 - accuracy: 0.9928 - val_loss: 0.0483 - val_accuracy: 0.9842
# Epoch 31/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9926
# Epoch 31: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.0383 - val_accuracy: 0.9908
# Epoch 32/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9939
# Epoch 32: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.0524 - val_accuracy: 0.9833
# Epoch 33/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9923
# Epoch 33: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0243 - val_accuracy: 0.9933
# Epoch 34/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9926
# Epoch 34: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0205 - accuracy: 0.9926 - val_loss: 0.0390 - val_accuracy: 0.9875
# Epoch 35/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9905
# Epoch 35: val_accuracy did not improve from 0.99333
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0246 - accuracy: 0.9905 - val_loss: 0.0320 - val_accuracy: 0.9900
# Epoch 36/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9948
# Epoch 36: val_accuracy improved from 0.99333 to 0.99583, saving model to model_weights.h5
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.0249 - val_accuracy: 0.9958
# Epoch 37/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9937
# Epoch 37: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 10s 38ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 38/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9950
# Epoch 38: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0611 - val_accuracy: 0.9850
# Epoch 39/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9962
# Epoch 39: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0436 - val_accuracy: 0.9900
# Epoch 40/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9919
# Epoch 40: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0196 - accuracy: 0.9919 - val_loss: 0.0514 - val_accuracy: 0.9833
# Epoch 41/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9930
# Epoch 41: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0158 - accuracy: 0.9930 - val_loss: 0.0476 - val_accuracy: 0.9858
# Epoch 42/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9932
# Epoch 42: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0187 - accuracy: 0.9930 - val_loss: 0.0313 - val_accuracy: 0.9892
# Epoch 43/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9950
# Epoch 43: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 32ms/step - loss: 0.0124 - accuracy: 0.9950 - val_loss: 0.0418 - val_accuracy: 0.9925
# Epoch 44/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9950
# Epoch 44: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 34ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0276 - val_accuracy: 0.9933
# Epoch 45/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 0.9946
# Epoch 45: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 33ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 0.0264 - val_accuracy: 0.9925
# Epoch 46/50
# 261/262 [============================>.] - ETA: 0s - loss: 0.0260 - accuracy: 0.9923
# Epoch 46: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 9s 35ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0261 - val_accuracy: 0.9875
# Epoch 47/50
# 262/262 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9948
# Epoch 47: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 8s 30ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0178 - val_accuracy: 0.9958
# Epoch 48/50
#  84/262 [========>.....................] - ETA: 5s - loss: 0.0118 - accuracy: 0.9944WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 13100 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 48: val_accuracy did not improve from 0.99583
# 262/262 [==============================] - 4s 17ms/step - loss: 0.0118 - accuracy: 0.9945 - val_loss: 0.0182 - val_accuracy: 0.9950

# %%
show_final_history(history)

# %%
val_pred = model.predict(val_images)
val_pred = np.argmax(val_pred,axis=1)
val_pred.shape
# Out:
# 38/38 [==============================] - 1s 10ms/step
# (1200,)

# %%
val_actual = np.argmax(val_labels,axis=1)

cnf_mat = confusion_matrix(val_actual, val_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat,classes=class_names)
plt.grid(None)
plt.show();

# %%
test_pred = model.predict(test_images)
test_pred = np.argmax(test_pred,axis=1)
test_pred.shape
# Out:
# 19/19 [==============================] - 0s 9ms/step
# (600,)

# %%
test_actual = np.argmax(test_labels,axis=1)

cnf_mat_test = confusion_matrix(test_actual, test_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat_test,classes=class_names)
plt.grid(None)
plt.show()

# %%
rnd_idx = random.sample(range(0,400),10)

class_labels = {i:class_name for (class_name,i) in class_name_labels.items()}
class_labels

# fig, ax = plt.subplots(2,5,figsize=(5,5))

for i,idx in enumerate(rnd_idx):
    
    plt.imshow(test_images[idx])
    plt.title("Actual: {}\nPredicted: {}".format(class_labels[test_actual[idx]],class_labels[test_pred[idx]]))
    plt.grid(None)
    plt.show()
    pass
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.save("ship-model.h5")
